# %% [markdown]
# ### KPI 3: Share renewable
# Calculates the share of grey energy consumed for every entity at every time step.
# The grey energy share can be multiplied by the grey energy's share of renewable (e.g. 42%) to obtain the entity's share renewable.
#
# #### Example: 01h:00m:00s
# - region-1-ec-1 has grey energy share of 1, i.e. it has a share renewable of 1 * 42% = 42%
# - region-2-ec-3-house-3 has grey energy share of 0.4, i.e. it has a share renewable of 0.4 * 42% = 16.8%
#
# #### Structure of result (preliminary)
# ``dict_out`` contains all the results. It has keys for each time step (here: 24h). Each time step-key again contains a dictionary with every entity at that timestep and its calculated grey energy share. For example, ``dict_out['2030-01-01T03:00:00+00:00']`` contains all entities' share grey energy for 03h:00m:00s (see below).
#
# As a next step, this result will be reshaped to a dataframe with time steps as index and entities as columns (TODO Jochen).
#
# ---

# %% [markdown]
# #### Setup
# As always, the ``home_path`` must be changed to your local filepath. Since this is a Jupyter Notebook, no helper functions must be imported (for now).

# %%
# set up
import os
import pandas as pd
import functools as func
import functions as f
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_style('white')
home_path = "C:\\Users\joche\FIM Kernkompetenzzentrum\Projekt VIdES - Dokumente\General\\07_Arbeitsordner\\04_Ergebnisse\\20220907_erste_Ergebnisse_UseCases"
os.chdir(home_path)
os.chdir('usecase2_edu/')

# %%
def share_renewable(file_path):
    df = pd.read_csv(file_path).drop(['creation_time', 'matching_requirements', 'rate [ct./kWh]'], axis=1)
    df.seller = [i.lower().replace('_', '-') for i in df.seller]
    df.buyer = [i.lower().replace('_', '-') for i in df.buyer]
    # p: parent entity name
    p = file_path.split('\\')[-1].split('-trades.csv')[0]
    # get children
    sellers = [i for i in df.seller.unique() if 'mm-' not in i and i != p]
    buyers = [i for i in df.buyer.unique() if 'mm-' not in i and i != p]
    children = pd.Series(sellers + buyers).unique()
    df.set_index(['slot'], inplace=True)
    for slot, df_slot in df.groupby(level=0):
        if len(dict_out.keys()) < 1 or slot not in dict_out.keys():
            dict_out[slot] = dict()
        # c: children entity name
        for c in children:
            # net energy child bought from parent
            p_to_c = df_slot[df_slot.seller.str.contains(p) &
                               (df_slot.buyer.str.contains(c))]['energy [kWh]'].sum()
            c_to_p = df_slot[df_slot.seller.str.contains(c) &
                               (df_slot.buyer.str.contains(p))]['energy [kWh]'].sum()
            net_p_to_c = p_to_c - c_to_p
            # net energy child bought from other children
            cs_to_c = df_slot[(~df_slot.seller.str.contains(p)) &
                                (~df_slot.seller.str.contains(c)) &
                                (df_slot.buyer.str.contains(c))]['energy [kWh]'].sum()
            c_to_cs = df_slot[(df_slot.seller.str.contains(c)) &
                                (~df_slot.buyer.str.contains(p)) &
                                (~df_slot.buyer.str.contains(c))]['energy [kWh]'].sum()
            net_cs_to_c = cs_to_c - c_to_cs
            # children's share grey electricity
            if net_p_to_c > 0 and net_cs_to_c <= 0:
                c_share_grey_electricity = 1 if p not in dict_out[slot].keys() else dict_out[slot][p]
            elif net_p_to_c > 0 and net_cs_to_c > 0:
                p_share_grey_electricity = 1 if p not in dict_out[slot].keys() else dict_out[slot][p]
                c_share_grey_electricity = p_share_grey_electricity * (net_p_to_c / (net_p_to_c + net_cs_to_c))
            else:
                c_share_grey_electricity = 0
            dict_out[slot][c] = c_share_grey_electricity

    return

# %% [markdown]
# #### Attention
# This cell excecutes the function and takes ~ 2m to complete. The variable ``dict_out`` can then be printed, assessed, etc.

# %%
dict_out = dict()
files = []
for root, dir, file in os.walk(top = home_path+'/usecase2_edu',topdown=True):
    files += [os.path.join(root,f) for f in file if 'trades.csv' in f]

for file in files:
    share_renewable(file)

# %%
dict_out.keys()
# Out:
# dict_keys(['2030-01-01T00:00:00+00:00', '2030-01-01T01:00:00+00:00', '2030-01-01T02:00:00+00:00', '2030-01-01T03:00:00+00:00', '2030-01-01T04:00:00+00:00', '2030-01-01T05:00:00+00:00', '2030-01-01T06:00:00+00:00', '2030-01-01T07:00:00+00:00', '2030-01-01T08:00:00+00:00', '2030-01-01T09:00:00+00:00', '2030-01-01T10:00:00+00:00', '2030-01-01T11:00:00+00:00', '2030-01-01T12:00:00+00:00', '2030-01-01T13:00:00+00:00', '2030-01-01T14:00:00+00:00', '2030-01-01T15:00:00+00:00', '2030-01-01T16:00:00+00:00', '2030-01-01T17:00:00+00:00', '2030-01-01T18:00:00+00:00', '2030-01-01T19:00:00+00:00', '2030-01-01T20:00:00+00:00', '2030-01-01T21:00:00+00:00', '2030-01-01T22:00:00+00:00', '2030-01-01T23:00:00+00:00'])

# %%
dict_out['2030-01-01T03:00:00+00:00']
# Out:
# {'grid': 1,
#  'region-1': 1,
#  'region-5': 1,
#  'region-4': 1,
#  'region-2': 1,
#  'region-3': 0.589452786658276,
#  'region-6': 0.7877469470556032,
#  'region-1-ec0': 0,
#  'region-1-ec3': 1,
#  'region-1-ec4': 1,
#  'region-1-ec1': 1,
#  'region-1-ec2': 1,
#  'region-1-ec5': 1,
#  'region-2-ec0': 0,
#  'region-2-ec1': 1,
#  'region-2-ec3': 1,
#  'region-2-ec4': 1,
#  'region-2-ec2': 1,
#  'region-2-ec5': 1,
#  'region-3-ec0': 0,
#  'region-3-ec4': 0.589452786658276,
#  'region-3-ec2': 0.589452786658276,
#  'region-3-ec3': 0.589452786658276,
#  'region-3-ec1': 0.589452786658276,
#  'region-3-ec5': 0.589452786658276,
#  'region-4-ec0': 0,
#  'region-4-ec4': 1,
#  'region-4-ec2': 1,
#  'region-4-ec3': 1,
#  'region-4-ec1': 1,
#  'region-4-ec5': 1,
#  'region-5-ec0': 0,
#  'region-5-ec3': 1,
#  'region-5-ec1': 1,
#  'region-5-ec2': 1,
#  'region-5-ec4': 1,
#  'region-5-ec5': 1,
#  'region-6-ec0': 0,
#  'region-6-ec1': 0.7877469470556032,
#  'region-6-ec4': 0.7877469470556032,
#  'region-6-ec2': 0.7877469470556032,
#  'region-6-ec3': 0.7877469470556032,
#  'region-6-ec5': 0.7877469470556032,
#  'region-1-ec0-house-wind': 0,
#  'region-1-ec1-house-14': 1,
#  'region-1-ec1-house-16': 1,
#  'region-1-ec1-house-3': 1,
#  'region-1-ec1-house-11': 1,
#  'region-1-ec1-house-1': 1,
#  'region-1-ec1-house-5': 1,
#  'region-1-ec1-house-15': 1,
#  'region-1-ec1-house-8': 1,
#  'region-1-ec1-house-12': 1,
#  'region-1-ec1-house-6': 1,
#  'region-1-ec1-house-7': 1,
#  'region-1-ec1-house-0': 1,
#  'region-1-ec1-house-9': 1,
#  'region-1-ec1-house-2': 1,
#  'region-1-ec1-house-13': 1,
#  'region-1-ec1-house-18': 1,
#  'region-1-ec1-house-17': 1,
#  'region-1-ec1-house-19': 1,
#  'region-1-ec1-house-10': 1,
#  'region-1-ec1-house-20': 1,
#  'region-1-ec1-house-4': 1,
#  'region-1-ec2-house-9': 1,
#  'region-1-ec2-house-21': 1,
#  'region-1-ec2-house-4': 1,
#  'region-1-ec2-house-5': 1,
#  'region-1-ec2-house-2': 1,
#  'region-1-ec2-house-15': 1,
#  'region-1-ec2-house-7': 1,
#  'region-1-ec2-house-20': 1,
#  'region-1-ec2-house-0': 1,
#  'region-1-ec2-house-10': 1,
#  'region-1-ec2-house-14': 1,
#  'region-1-ec2-house-6': 1,
#  'region-1-ec2-house-16': 1,
#  'region-1-ec2-house-1': 1,
#  'region-1-ec2-house-13': 1,
#  'region-1-ec2-house-8': 1,
#  'region-1-ec2-house-18': 1,
#  'region-1-ec2-house-12': 1,
#  'region-1-ec2-house-11': 1,
#  'region-1-ec2-house-19': 1,
#  'region-1-ec2-house-17': 1,
#  'region-1-ec2-house-3': 1,
#  'region-1-ec3-house-16': 1,
#  'region-1-ec3-house-12': 1,
#  'region-1-ec3-house-11': 1,
#  'region-1-ec3-house-8': 1,
#  'region-1-ec3-house-15': 1,
#  'region-1-ec3-house-5': 1,
#  'region-1-ec3-house-2': 1,
#  'region-1-ec3-house-10': 1,
#  'region-1-ec3-house-6': 1,
#  'region-1-ec3-house-1': 1,
#  'region-1-ec3-house-7': 1,
#  'region-1-ec3-house-17': 1,
#  'region-1-ec3-house-21': 1,
#  'region-1-ec3-house-3': 1,
#  'region-1-ec3-house-9': 1,
#  'region-1-ec3-house-19': 1,
#  'region-1-ec3-house-18': 1,
#  'region-1-ec3-house-0': 1,
#  'region-1-ec3-house-14': 1,
#  'region-1-ec3-house-20': 1,
#  'region-1-ec3-house-13': 1,
#  'region-1-ec3-house-4': 1,
#  'region-1-ec4-house-10': 1,
#  'region-1-ec4-house-11': 1,
#  'region-1-ec4-house-15': 1,
#  'region-1-ec4-house-16': 1,
#  'region-1-ec4-house-7': 1,
#  'region-1-ec4-house-4': 1,
#  'region-1-ec4-house-18': 1,
#  'region-1-ec4-house-6': 1,
#  'region-1-ec4-house-3': 1,
#  'region-1-ec4-house-12': 1,
#  'region-1-ec4-house-9': 1,
#  'region-1-ec4-house-1': 1,
#  'region-1-ec4-house-21': 1,
#  'region-1-ec4-house-8': 1,
#  'region-1-ec4-house-17': 1,
#  'region-1-ec4-house-14': 1,
#  'region-1-ec4-house-0': 1,
#  'region-1-ec4-house-5': 1,
#  'region-1-ec4-house-19': 1,
#  'region-1-ec4-house-20': 1,
#  'region-1-ec4-house-13': 1,
#  'region-1-ec4-house-2': 1,
#  'region-1-ec5-house-industry': 1,
#  'region-1-id-1-wind-feedin': 0,
#  'region-1-id-1-hh-1-household-electric-load': 1,
#  'region-1-id-2-hh-1-household-electric-load': 1,
#  'id-2-ev-non-commuter': 0.7877469470556032,
#  'region-1-id-41-hh-2-household-electric-load': 1,
#  'region-1-id-42-hh-2-household-electric-load': 1,
#  'id-3-ev-hhchild': 0.7877469470556032,
#  'region-1-id-43-hh-2-household-electric-load': 1,
#  'id-5-ev-pensioner': 0.7877469470556032,
#  'region-1-id-44-hh-2-household-electric-load': 1,
#  'region-1-id-2-pv-feedin': 0,
#  'region-1-id-45-hh-2-household-electric-load': 1,
#  'region-1-id-46-hh-2-household-electric-load': 1,
#  'id-1-ev-commuter': 0.7877469470556032,
#  'region-1-id-2-heatpump-loadprofile': 1,
#  'region-1-id-1-pv-feedin': 0,
#  'region-1-id-68-hh-3-household-electric-load': 1,
#  'region-1-id-69-hh-3-household-electric-load': 1,
#  'region-1-id-70-hh-3-household-electric-load': 1,
#  'region-1-id-77-hh-4-household-electric-load': 1,
#  'region-1-id-3-hh-1-household-electric-load': 1,
#  'region-1-id-84-hh-5-household-electric-load': 1,
#  'region-1-id-4-hh-1-household-electric-load': 1,
#  'region-1-id-5-hh-1-household-electric-load': 1,
#  'region-1-id-6-hh-1-household-electric-load': 1,
#  'region-1-id-7-hh-1-household-electric-load': 1,
#  'region-1-id-1-heatpump-loadprofile': 1,
#  'region-1-id-8-hh-1-household-electric-load': 1,
#  'id-4-ev-hhnochild': 0.7877469470556032,
#  'region-1-id-9-hh-1-household-electric-load': 1,
#  'id-6-ev-commuter': 0.7877469470556032,
#  'region-1-id-40-hh-2-household-electric-load': 1,
#  'region-1-id-10-hh-1-household-electric-load': 1,
#  'region-1-id-3-heatpump-loadprofile': 1,
#  'region-1-id-11-hh-1-household-electric-load': 1,
#  'region-1-id-47-hh-2-household-electric-load': 1,
#  'region-1-id-48-hh-2-household-electric-load': 1,
#  'region-1-id-49-hh-2-household-electric-load': 1,
#  'region-1-id-50-hh-2-household-electric-load': 1,
#  'region-1-id-51-hh-2-household-electric-load': 1,
#  'region-1-id-52-hh-2-household-electric-load': 1,
#  'region-1-id-4-heatpump-loadprofile': 1,
#  'region-1-id-53-hh-2-household-electric-load': 1,
#  'region-1-id-71-hh-3-household-electric-load': 1,
#  'region-1-id-72-hh-3-household-electric-load': 1,
#  'region-1-id-78-hh-4-household-electric-load': 1,
#  'region-1-id-12-hh-1-household-electric-load': 1,
#  'region-1-id-79-hh-4-household-electric-load': 1,
#  'region-1-id-3-pv-feedin': 0,
#  'region-1-id-85-hh-5-household-electric-load': 1,
#  'region-1-id-13-hh-1-household-electric-load': 1,
#  'id-1-data-batterystorage': 0,
#  'region-1-id-14-hh-1-household-electric-load': 1,
#  'region-1-id-15-hh-1-household-electric-load': 1,
#  'region-1-id-16-hh-1-household-electric-load': 1,
#  'region-1-id-17-hh-1-household-electric-load': 1,
#  'region-1-id-18-hh-1-household-electric-load': 1,
#  'region-1-id-4-pv-feedin': 0,
#  'region-1-id-19-hh-1-household-electric-load': 1,
#  'region-1-id-20-hh-1-household-electric-load': 1,
#  'region-1-id-21-hh-1-household-electric-load': 1,
#  'region-1-id-54-hh-2-household-electric-load': 1,
#  'id-2-data-batterystorage': 0,
#  'region-1-id-55-hh-2-household-electric-load': 1,
#  'region-1-id-6-pv-feedin': 0,
#  'region-1-id-56-hh-2-household-electric-load': 1,
#  'region-1-id-57-hh-2-household-electric-load': 1,
#  'region-1-id-58-hh-2-household-electric-load': 1,
#  'region-1-id-6-heatpump-loadprofile': 1,
#  'region-1-id-59-hh-2-household-electric-load': 1,
#  'region-1-id-5-pv-feedin': 0,
#  'region-1-id-60-hh-2-household-electric-load': 1,
#  'region-1-id-73-hh-3-household-electric-load': 1,
#  'region-1-id-74-hh-3-household-electric-load': 1,
#  'region-1-id-80-hh-4-household-electric-load': 1,
#  'region-1-id-22-hh-1-household-electric-load': 1,
#  'region-1-id-81-hh-4-household-electric-load': 1,
#  'region-1-id-86-hh-5-household-electric-load': 1,
#  'region-1-id-23-hh-1-household-electric-load': 1,
#  'region-1-id-24-hh-1-household-electric-load': 1,
#  'region-1-id-25-hh-1-household-electric-load': 1,
#  'region-1-id-26-hh-1-household-electric-load': 1,
#  'region-1-id-27-hh-1-household-electric-load': 1,
#  'region-1-id-28-hh-1-household-electric-load': 1,
#  'region-1-id-5-heatpump-loadprofile': 1,
#  'region-1-id-29-hh-1-household-electric-load': 1,
#  'region-1-id-30-hh-1-household-electric-load': 1,
#  'region-1-id-31-hh-1-household-electric-load': 1,
#  'region-1-id-8-pv-feedin': 0,
#  'region-1-id-61-hh-2-household-electric-load': 1,
#  'region-1-id-7-pv-feedin': 0,
#  'region-1-id-62-hh-2-household-electric-load': 1,
#  'region-1-id-63-hh-2-household-electric-load': 1,
#  'region-1-id-64-hh-2-household-electric-load': 1,
#  'region-1-id-65-hh-2-household-electric-load': 1,
#  'region-1-id-8-heatpump-loadprofile': 1,
#  'id-3-data-batterystorage': 0,
#  'region-1-id-66-hh-2-household-electric-load': 1,
#  'region-1-id-7-heatpump-loadprofile': 1,
#  'region-1-id-67-hh-2-household-electric-load': 1,
#  'region-1-id-75-hh-3-household-electric-load': 1,
#  'region-1-id-76-hh-3-household-electric-load': 1,
#  'region-1-id-82-hh-4-household-electric-load': 1,
#  'region-1-id-32-hh-1-household-electric-load': 1,
#  'region-1-id-83-hh-4-household-electric-load': 1,
#  'region-1-id-87-hh-5-household-electric-load': 1,
#  'region-1-id-33-hh-1-household-electric-load': 1,
#  'region-1-id-34-hh-1-household-electric-load': 1,
#  'region-1-id-35-hh-1-household-electric-load': 1,
#  'region-1-id-36-hh-1-household-electric-load': 1,
#  'region-1-id-37-hh-1-household-electric-load': 1,
#  'region-1-id-38-hh-1-household-electric-load': 1,
#  'region-1-id-39-hh-1-household-electric-load': 1,
#  'region-1-industry-electric-load': 1,
#  'region-2-ec0-house-wind': 0,
#  'region-2-ec1-house-21': 1,
#  'region-2-ec1-house-39': 1,
#  'region-2-ec1-house-34': 1,
#  'region-2-ec1-house-20': 1,
#  'region-2-ec1-house-27': 1,
#  'region-2-ec1-house-3': 1,
#  'region-2-ec1-house-32': 1,
#  'region-2-ec1-house-18': 1,
#  'region-2-ec1-house-16': 1,
#  'region-2-ec1-house-12': 1,
#  'region-2-ec1-house-26': 1,
#  'region-2-ec1-house-8': 1,
#  'region-2-ec1-house-2': 1,
#  'region-2-ec1-house-23': 1,
#  'region-2-ec1-house-25': 1,
#  'region-2-ec1-house-13': 1,
#  'region-2-ec1-house-15': 1,
#  'region-2-ec1-house-22': 1,
#  'region-2-ec1-house-24': 1,
#  'region-2-ec1-house-11': 1,
#  'region-2-ec1-house-17': 1,
#  'region-2-ec1-house-9': 1,
#  'region-2-ec1-house-1': 1,
#  'region-2-ec1-house-37': 1,
#  'region-2-ec1-house-7': 1,
#  'region-2-ec1-house-28': 1,
#  'region-2-ec1-house-38': 1,
#  'region-2-ec1-house-19': 1,
#  'region-2-ec1-house-30': 1,
#  'region-2-ec1-house-6': 1,
#  'region-2-ec1-house-35': 1,
#  'region-2-ec1-house-31': 1,
#  'region-2-ec1-house-4': 1,
#  'region-2-ec1-house-33': 1,
#  'region-2-ec1-house-14': 1,
#  'region-2-ec1-house-10': 1,
#  'region-2-ec1-house-5': 1,
#  'region-2-ec1-house-29': 1,
#  'region-2-ec1-house-0': 1,
#  'region-2-ec1-house-36': 1,
#  'region-2-ec1-house-40': 1,
#  'region-2-ec1-house-41': 1,
#  'region-2-ec2-house-6': 1,
#  'region-2-ec2-house-4': 1,
#  'region-2-ec2-house-0': 1,
#  'region-2-ec2-house-2': 1,
#  'region-2-ec2-house-38': 1,
#  'region-2-ec2-house-25': 1,
#  'region-2-ec2-house-22': 1,
#  'region-2-ec2-house-8': 1,
#  'region-2-ec2-house-40': 1,
#  'region-2-ec2-house-26': 1,
#  'region-2-ec2-house-10': 1,
#  'region-2-ec2-house-29': 1,
#  'region-2-ec2-house-19': 1,
#  'region-2-ec2-house-16': 1,
#  'region-2-ec2-house-24': 1,
#  'region-2-ec2-house-34': 1,
#  'region-2-ec2-house-13': 1,
#  'region-2-ec2-house-27': 1,
#  'region-2-ec2-house-18': 1,
#  'region-2-ec2-house-7': 1,
#  'region-2-ec2-house-17': 1,
#  'region-2-ec2-house-1': 1,
#  'region-2-ec2-house-14': 1,
#  'region-2-ec2-house-12': 1,
#  'region-2-ec2-house-39': 1,
#  'region-2-ec2-house-33': 1,
#  'region-2-ec2-house-5': 1,
#  'region-2-ec2-house-31': 1,
#  'region-2-ec2-house-35': 1,
#  'region-2-ec2-house-36': 1,
#  'region-2-ec2-house-30': 1,
#  'region-2-ec2-house-32': 1,
#  'region-2-ec2-house-23': 1,
#  'region-2-ec2-house-42': 1,
#  'region-2-ec2-house-28': 1,
#  'region-2-ec2-house-15': 1,
#  'region-2-ec2-house-41': 1,
#  'region-2-ec2-house-9': 1,
#  'region-2-ec2-house-21': 1,
#  'region-2-ec2-house-11': 1,
#  'region-2-ec2-house-20': 1,
#  'region-2-ec2-house-3': 1,
#  'region-2-ec2-house-37': 1,
#  'region-2-ec3-house-14': 1,
#  'region-2-ec3-house-8': 1,
#  'region-2-ec3-house-18': 1,
#  'region-2-ec3-house-16': 1,
#  'region-2-ec3-house-7': 1,
#  'region-2-ec3-house-39': 1,
#  'region-2-ec3-house-41': 1,
#  'region-2-ec3-house-4': 1,
#  'region-2-ec3-house-28': 1,
#  'region-2-ec3-house-19': 1,
#  'region-2-ec3-house-15': 1,
#  'region-2-ec3-house-30': 1,
#  'region-2-ec3-house-40': 1,
#  'region-2-ec3-house-38': 1,
#  'region-2-ec3-house-42': 1,
#  'region-2-ec3-house-24': 1,
#  'region-2-ec3-house-2': 1,
#  'region-2-ec3-house-37': 1,
#  'region-2-ec3-house-17': 1,
#  'region-2-ec3-house-11': 1,
#  'region-2-ec3-house-13': 1,
#  'region-2-ec3-house-31': 1,
#  'region-2-ec3-house-23': 1,
#  'region-2-ec3-house-3': 1,
#  'region-2-ec3-house-0': 1,
#  'region-2-ec3-house-5': 1,
#  'region-2-ec3-house-35': 1,
#  'region-2-ec3-house-29': 1,
#  'region-2-ec3-house-22': 1,
#  'region-2-ec3-house-21': 1,
#  'region-2-ec3-house-25': 1,
#  'region-2-ec3-house-33': 1,
#  'region-2-ec3-house-26': 1,
#  'region-2-ec3-house-9': 1,
#  'region-2-ec3-house-32': 1,
#  'region-2-ec3-house-34': 1,
#  'region-2-ec3-house-27': 1,
#  'region-2-ec3-house-1': 1,
#  'region-2-ec3-house-12': 1,
#  'region-2-ec3-house-20': 1,
#  'region-2-ec3-house-10': 1,
#  'region-2-ec3-house-36': 1,
#  'region-2-ec3-house-6': 1,
#  'region-2-ec4-house-37': 1,
#  'region-2-ec4-house-24': 1,
#  'region-2-ec4-house-18': 1,
#  'region-2-ec4-house-10': 1,
#  'region-2-ec4-house-7': 1,
#  'region-2-ec4-house-9': 1,
#  'region-2-ec4-house-13': 1,
#  'region-2-ec4-house-21': 1,
#  'region-2-ec4-house-16': 1,
#  'region-2-ec4-house-28': 1,
#  'region-2-ec4-house-15': 1,
#  'region-2-ec4-house-22': 1,
#  'region-2-ec4-house-12': 1,
#  'region-2-ec4-house-29': 1,
#  'region-2-ec4-house-8': 1,
#  'region-2-ec4-house-25': 1,
#  'region-2-ec4-house-2': 1,
#  'region-2-ec4-house-23': 1,
#  'region-2-ec4-house-32': 1,
#  'region-2-ec4-house-17': 1,
#  'region-2-ec4-house-35': 1,
#  'region-2-ec4-house-19': 1,
#  'region-2-ec4-house-38': 1,
#  'region-2-ec4-house-14': 1,
#  'region-2-ec4-house-0': 1,
#  'region-2-ec4-house-42': 1,
#  'region-2-ec4-house-40': 1,
#  'region-2-ec4-house-36': 1,
#  'region-2-ec4-house-27': 1,
#  'region-2-ec4-house-20': 1,
#  'region-2-ec4-house-33': 1,
#  'region-2-ec4-house-31': 1,
#  'region-2-ec4-house-4': 1,
#  'region-2-ec4-house-1': 1,
#  'region-2-ec4-house-5': 1,
#  'region-2-ec4-house-39': 1,
#  'region-2-ec4-house-41': 1,
#  'region-2-ec4-house-3': 1,
#  'region-2-ec4-house-11': 1,
#  'region-2-ec4-house-30': 1,
#  'region-2-ec4-house-26': 1,
#  'region-2-ec4-house-34': 1,
#  'region-2-ec4-house-6': 1,
#  'region-2-ec5-house-industry': 1,
#  'region-2-id-2-wind-feedin': 0,
#  'region-2-id-88-hh-1-household-electric-load': 1,
#  'region-2-id-89-hh-1-household-electric-load': 1,
#  'id-7-ev-non-commuter': 0.7877469470556032,
#  'region-2-id-98-hh-1-household-electric-load': 1,
#  'region-2-id-99-hh-1-household-electric-load': 1,
#  'region-2-id-11-heatpump-loadprofile': 1,
#  'region-2-id-100-hh-1-household-electric-load': 1,
#  'region-2-id-101-hh-1-household-electric-load': 1,
#  'region-2-id-102-hh-1-household-electric-load': 1,
#  'region-2-id-103-hh-1-household-electric-load': 1,
#  'region-2-id-104-hh-1-household-electric-load': 1,
#  'id-12-ev-non-commuter': 1,
#  'region-2-id-156-hh-2-household-electric-load': 1,
#  'id-4-data-batterystorage': 0,
#  'region-2-id-157-hh-2-household-electric-load': 1,
#  'region-2-id-158-hh-2-household-electric-load': 1,
#  'region-2-id-90-hh-1-household-electric-load': 1,
#  'region-2-id-13-pv-feedin': 0,
#  'id-13-ev-hhchild': 1,
#  'region-2-id-159-hh-2-household-electric-load': 1,
#  'region-2-id-12-pv-feedin': 0,
#  'region-2-id-160-hh-2-household-electric-load': 1,
#  'region-2-id-161-hh-2-household-electric-load': 1,
#  'id-8-ev-hhchild': 0.7877469470556032,
#  'region-2-id-162-hh-2-household-electric-load': 1,
#  'region-2-id-163-hh-2-household-electric-load': 1,
#  'region-2-id-164-hh-2-household-electric-load': 1,
#  'region-2-id-165-hh-2-household-electric-load': 1,
#  'region-2-id-10-pv-feedin': 0,
#  'region-2-id-166-hh-2-household-electric-load': 1,
#  'region-2-id-167-hh-2-household-electric-load': 1,
#  'region-2-id-168-hh-2-household-electric-load': 1,
#  'region-2-id-15-pv-feedin': 0,
#  'region-2-id-91-hh-1-household-electric-load': 1,
#  'region-2-id-10-heatpump-loadprofile': 1,
#  'region-2-id-169-hh-2-household-electric-load': 1,
#  'id-10-ev-pensioner': 0.7877469470556032,
#  'region-2-id-170-hh-2-household-electric-load': 1,
#  'region-2-id-11-pv-feedin': 0,
#  'region-2-id-216-hh-3-household-electric-load': 1,
#  'region-2-id-9-heatpump-loadprofile': 1,
#  'region-2-id-217-hh-3-household-electric-load': 1,
#  'region-2-id-14-pv-feedin': 0,
#  'region-2-id-218-hh-3-household-electric-load': 1,
#  'region-2-id-219-hh-3-household-electric-load': 1,
#  'region-2-id-220-hh-3-household-electric-load': 1,
#  'id-9-ev-hhnochild': 0.7877469470556032,
#  'region-2-id-236-hh-4-household-electric-load': 1,
#  'region-2-id-237-hh-4-household-electric-load': 1,
#  'region-2-id-9-pv-feedin': 0,
#  'id-14-ev-hhnochild': 1,
#  'region-2-id-238-hh-4-household-electric-load': 1,
#  'region-2-id-92-hh-1-household-electric-load': 1,
#  'region-2-id-239-hh-4-household-electric-load': 1,
#  'region-2-id-252-hh-5-household-electric-load': 1,
#  'region-2-id-93-hh-1-household-electric-load': 1,
#  'id-15-ev-pensioner': 1,
#  'region-2-id-94-hh-1-household-electric-load': 1,
#  'region-2-id-95-hh-1-household-electric-load': 1,
#  'region-2-id-96-hh-1-household-electric-load': 1,
#  'id-11-ev-commuter': 1,
#  'region-2-id-12-heatpump-loadprofile': 1,
#  'region-2-id-97-hh-1-household-electric-load': 1,
#  'region-2-id-22-pv-feedin': 0,
#  'region-2-id-105-hh-1-household-electric-load': 1,
#  'id-16-ev-commuter': 1,
#  'region-2-id-106-hh-1-household-electric-load': 1,
#  'region-2-id-115-hh-1-household-electric-load': 1,
#  'region-2-id-116-hh-1-household-electric-load': 1,
#  'region-2-id-15-heatpump-loadprofile': 1,
#  'region-2-id-117-hh-1-household-electric-load': 1,
#  'region-2-id-118-hh-1-household-electric-load': 1,
#  'id-17-ev-non-commuter': 1,
#  'region-2-id-119-hh-1-household-electric-load': 1,
#  'region-2-id-120-hh-1-household-electric-load': 1,
#  'region-2-id-121-hh-1-household-electric-load': 1,
#  'region-2-id-171-hh-2-household-electric-load': 1,
#  'region-2-id-14-heatpump-loadprofile': 1,
#  'region-2-id-172-hh-2-household-electric-load': 1,
#  'region-2-id-16-heatpump-loadprofile': 1,
#  'region-2-id-173-hh-2-household-electric-load': 1,
#  'region-2-id-16-pv-feedin': 0,
#  'region-2-id-107-hh-1-household-electric-load': 1,
#  'region-2-id-174-hh-2-household-electric-load': 1,
#  'region-2-id-175-hh-2-household-electric-load': 1,
#  'region-2-id-19-pv-feedin': 0,
#  'region-2-id-176-hh-2-household-electric-load': 1,
#  'region-2-id-13-heatpump-loadprofile': 1,
#  'region-2-id-177-hh-2-household-electric-load': 1,
#  'region-2-id-178-hh-2-household-electric-load': 1,
#  'region-2-id-21-pv-feedin': 0,
#  'id-5-data-batterystorage': 0,
#  'region-2-id-179-hh-2-household-electric-load': 1,
#  'region-2-id-180-hh-2-household-electric-load': 1,
#  'region-2-id-181-hh-2-household-electric-load': 1,
#  'region-2-id-182-hh-2-household-electric-load': 1,
#  'region-2-id-183-hh-2-household-electric-load': 1,
#  'region-2-id-108-hh-1-household-electric-load': 1,
#  'region-2-id-184-hh-2-household-electric-load': 1,
#  'region-2-id-185-hh-2-household-electric-load': 1,
#  'region-2-id-221-hh-3-household-electric-load': 1,
#  'region-2-id-222-hh-3-household-electric-load': 1,
#  'region-2-id-223-hh-3-household-electric-load': 1,
#  'region-2-id-224-hh-3-household-electric-load': 1,
#  'region-2-id-225-hh-3-household-electric-load': 1,
#  'region-2-id-240-hh-4-household-electric-load': 1,
#  'region-2-id-17-pv-feedin': 0,
#  'region-2-id-241-hh-4-household-electric-load': 1,
#  'region-2-id-242-hh-4-household-electric-load': 1,
#  'region-2-id-18-pv-feedin': 0,
#  'region-2-id-109-hh-1-household-electric-load': 1,
#  'region-2-id-243-hh-4-household-electric-load': 1,
#  'region-2-id-253-hh-5-household-electric-load': 1,
#  'region-2-id-254-hh-5-household-electric-load': 1,
#  'region-2-id-110-hh-1-household-electric-load': 1,
#  'region-2-id-20-pv-feedin': 0,
#  'region-2-id-111-hh-1-household-electric-load': 1,
#  'region-2-id-112-hh-1-household-electric-load': 1,
#  'id-6-data-batterystorage': 0,
#  'region-2-id-113-hh-1-household-electric-load': 1,
#  'region-2-id-114-hh-1-household-electric-load': 1,
#  'region-2-id-122-hh-1-household-electric-load': 1,
#  'region-2-id-18-heatpump-loadprofile': 1,
#  'region-2-id-123-hh-1-household-electric-load': 1,
#  'region-2-id-132-hh-1-household-electric-load': 1,
#  'region-2-id-133-hh-1-household-electric-load': 1,
#  'region-2-id-134-hh-1-household-electric-load': 1,
#  'region-2-id-135-hh-1-household-electric-load': 1,
#  'region-2-id-29-pv-feedin': 0,
#  'region-2-id-136-hh-1-household-electric-load': 1,
#  'region-2-id-137-hh-1-household-electric-load': 1,
#  'region-2-id-26-pv-feedin': 0,
#  'region-2-id-138-hh-1-household-electric-load': 1,
#  'region-2-id-186-hh-2-household-electric-load': 1,
#  'region-2-id-28-pv-feedin': 0,
#  'region-2-id-187-hh-2-household-electric-load': 1,
#  'region-2-id-188-hh-2-household-electric-load': 1,
#  'region-2-id-124-hh-1-household-electric-load': 1,
#  'region-2-id-189-hh-2-household-electric-load': 1,
#  'region-2-id-190-hh-2-household-electric-load': 1,
#  'region-2-id-191-hh-2-household-electric-load': 1,
#  'region-2-id-192-hh-2-household-electric-load': 1,
#  'region-2-id-193-hh-2-household-electric-load': 1,
#  'region-2-id-194-hh-2-household-electric-load': 1,
#  'region-2-id-195-hh-2-household-electric-load': 1,
#  'region-2-id-196-hh-2-household-electric-load': 1,
#  'id-8-data-batterystorage': 0,
#  'region-2-id-197-hh-2-household-electric-load': 1,
#  'region-2-id-198-hh-2-household-electric-load': 1,
#  'region-2-id-125-hh-1-household-electric-load': 1,
#  'region-2-id-199-hh-2-household-electric-load': 1,
#  'region-2-id-17-heatpump-loadprofile': 1,
#  'region-2-id-200-hh-2-household-electric-load': 1,
#  'region-2-id-226-hh-3-household-electric-load': 1,
#  'region-2-id-20-heatpump-loadprofile': 1,
#  'region-2-id-227-hh-3-household-electric-load': 1,
#  'region-2-id-228-hh-3-household-electric-load': 1,
#  'region-2-id-229-hh-3-household-electric-load': 1,
#  'region-2-id-230-hh-3-household-electric-load': 1,
#  'region-2-id-244-hh-4-household-electric-load': 1,
#  'region-2-id-19-heatpump-loadprofile': 1,
#  'region-2-id-245-hh-4-household-electric-load': 1,
#  'region-2-id-27-pv-feedin': 0,
#  'region-2-id-246-hh-4-household-electric-load': 1,
#  'id-7-data-batterystorage': 0,
#  'region-2-id-126-hh-1-household-electric-load': 1,
#  'region-2-id-247-hh-4-household-electric-load': 1,
#  'region-2-id-23-pv-feedin': 0,
#  'region-2-id-255-hh-5-household-electric-load': 1,
#  'region-2-id-256-hh-5-household-electric-load': 1,
#  'region-2-id-127-hh-1-household-electric-load': 1,
#  'region-2-id-128-hh-1-household-electric-load': 1,
#  'region-2-id-24-pv-feedin': 0,
#  'region-2-id-129-hh-1-household-electric-load': 1,
#  'region-2-id-25-pv-feedin': 0,
#  'region-2-id-130-hh-1-household-electric-load': 1,
#  'region-2-id-131-hh-1-household-electric-load': 1,
#  'region-2-id-139-hh-1-household-electric-load': 1,
#  'region-2-id-140-hh-1-household-electric-load': 1,
#  'region-2-id-30-pv-feedin': 0,
#  'region-2-id-149-hh-1-household-electric-load': 1,
#  'region-2-id-150-hh-1-household-electric-load': 1,
#  'region-2-id-151-hh-1-household-electric-load': 1,
#  'region-2-id-32-pv-feedin': 0,
#  'id-9-data-batterystorage': 0,
#  'region-2-id-152-hh-1-household-electric-load': 1,
#  'region-2-id-153-hh-1-household-electric-load': 1,
#  'region-2-id-154-hh-1-household-electric-load': 1,
#  'region-2-id-155-hh-1-household-electric-load': 1,
#  'region-2-id-201-hh-2-household-electric-load': 1,
#  'region-2-id-35-pv-feedin': 0,
#  'region-2-id-202-hh-2-household-electric-load': 1,
#  'region-2-id-203-hh-2-household-electric-load': 1,
#  'region-2-id-141-hh-1-household-electric-load': 1,
#  'region-2-id-22-heatpump-loadprofile': 1,
#  'region-2-id-204-hh-2-household-electric-load': 1,
#  'region-2-id-205-hh-2-household-electric-load': 1,
#  'region-2-id-206-hh-2-household-electric-load': 1,
#  'region-2-id-207-hh-2-household-electric-load': 1,
#  'region-2-id-34-pv-feedin': 0,
#  'region-2-id-208-hh-2-household-electric-load': 1,
#  'region-2-id-209-hh-2-household-electric-load': 1,
#  'region-2-id-23-heatpump-loadprofile': 1,
#  'region-2-id-210-hh-2-household-electric-load': 1,
#  'region-2-id-211-hh-2-household-electric-load': 1,
#  'region-2-id-212-hh-2-household-electric-load': 1,
#  'region-2-id-213-hh-2-household-electric-load': 1,
#  'region-2-id-21-heatpump-loadprofile': 1,
#  'region-2-id-142-hh-1-household-electric-load': 1,
#  'region-2-id-214-hh-2-household-electric-load': 1,
#  'region-2-id-215-hh-2-household-electric-load': 1,
#  'region-2-id-231-hh-3-household-electric-load': 1,
#  'region-2-id-232-hh-3-household-electric-load': 1,
#  'region-2-id-233-hh-3-household-electric-load': 1,
#  'region-2-id-234-hh-3-household-electric-load': 1,
#  'region-2-id-235-hh-3-household-electric-load': 1,
#  'region-2-id-33-pv-feedin': 0,
#  'region-2-id-248-hh-4-household-electric-load': 1,
#  'region-2-id-249-hh-4-household-electric-load': 1,
#  'region-2-id-250-hh-4-household-electric-load': 1,
#  'region-2-id-143-hh-1-household-electric-load': 1,
#  'region-2-id-251-hh-4-household-electric-load': 1,
#  'id-10-data-batterystorage': 0,
#  'region-2-id-257-hh-5-household-electric-load': 1,
#  'region-2-id-258-hh-5-household-electric-load': 1,
#  'region-2-id-144-hh-1-household-electric-load': 1,
#  'region-2-id-145-hh-1-household-electric-load': 1,
#  'region-2-id-36-pv-feedin': 0,
#  'region-2-id-146-hh-1-household-electric-load': 1,
#  'region-2-id-147-hh-1-household-electric-load': 1,
#  'region-2-id-31-pv-feedin': 0,
#  'region-2-id-148-hh-1-household-electric-load': 1,
#  'region-2-id-24-heatpump-loadprofile': 1,
#  'region-2-industry-electric-load': 1,
#  'region-3-ec0-house-wind': 0,
#  'region-3-ec1-house-4': 0.589452786658276,
#  'region-3-ec1-house-9': 0.589452786658276,
#  'region-3-ec1-house-7': 0.589452786658276,
#  'region-3-ec1-house-12': 0.589452786658276,
#  'region-3-ec1-house-11': 0.589452786658276,
#  'region-3-ec1-house-13': 0.589452786658276,
#  'region-3-ec1-house-0': 0.589452786658276,
#  'region-3-ec1-house-14': 0.589452786658276,
#  'region-3-ec1-house-6': 0.589452786658276,
#  'region-3-ec1-house-2': 0.589452786658276,
#  'region-3-ec1-house-3': 0.589452786658276,
#  'region-3-ec1-house-8': 0.589452786658276,
#  'region-3-ec1-house-5': 0.589452786658276,
#  'region-3-ec1-house-1': 0.589452786658276,
#  'region-3-ec1-house-10': 0.589452786658276,
#  'region-3-ec2-house-7': 0.589452786658276,
#  'region-3-ec2-house-8': 0.589452786658276,
#  'region-3-ec2-house-12': 0.589452786658276,
#  'region-3-ec2-house-10': 0.589452786658276,
#  'region-3-ec2-house-13': 0.589452786658276,
#  'region-3-ec2-house-4': 0.589452786658276,
#  'region-3-ec2-house-5': 0.589452786658276,
#  'region-3-ec2-house-2': 0.589452786658276,
#  'region-3-ec2-house-1': 0.589452786658276,
#  'region-3-ec2-house-6': 0.589452786658276,
#  'region-3-ec2-house-0': 0.589452786658276,
#  'region-3-ec2-house-9': 0.589452786658276,
#  'region-3-ec2-house-11': 0.589452786658276,
#  'region-3-ec2-house-3': 0.589452786658276,
#  'region-3-ec3-house-7': 0.589452786658276,
#  'region-3-ec3-house-8': 0.589452786658276,
#  'region-3-ec3-house-12': 0.589452786658276,
#  'region-3-ec3-house-2': 0.589452786658276,
#  'region-3-ec3-house-11': 0.589452786658276,
#  'region-3-ec3-house-1': 0.589452786658276,
#  'region-3-ec3-house-9': 0.589452786658276,
#  'region-3-ec3-house-13': 0.589452786658276,
#  'region-3-ec3-house-5': 0.589452786658276,
#  'region-3-ec3-house-4': 0.589452786658276,
#  'region-3-ec3-house-10': 0.589452786658276,
#  'region-3-ec3-house-6': 0.589452786658276,
#  'region-3-ec3-house-0': 0.589452786658276,
#  'region-3-ec3-house-3': 0.589452786658276,
#  'region-3-ec4-house-1': 0.589452786658276,
#  'region-3-ec4-house-8': 0.589452786658276,
#  'region-3-ec4-house-7': 0.589452786658276,
#  'region-3-ec4-house-4': 0.589452786658276,
#  'region-3-ec4-house-12': 0.589452786658276,
#  'region-3-ec4-house-3': 0.589452786658276,
#  'region-3-ec4-house-6': 0.589452786658276,
#  'region-3-ec4-house-10': 0.589452786658276,
#  'region-3-ec4-house-5': 0.589452786658276,
#  'region-3-ec4-house-13': 0.589452786658276,
#  'region-3-ec4-house-2': 0.589452786658276,
#  'region-3-ec4-house-11': 0.589452786658276,
#  'region-3-ec4-house-9': 0.589452786658276,
#  'region-3-ec4-house-0': 0.589452786658276,
#  'region-3-ec5-house-industry': 0.589452786658276,
#  'region-3-id-3-wind-feedin': 0,
#  'region-3-id-259-hh-1-household-electric-load': 0.589452786658276,
#  'region-3-id-260-hh-1-household-electric-load': 0.589452786658276,
#  'region-3-id-287-hh-2-household-electric-load': 0.589452786658276,
#  'region-3-id-288-hh-2-household-electric-load': 0.589452786658276,
#  'region-3-id-304-hh-3-household-electric-load': 0.589452786658276,
#  'region-3-id-26-heatpump-loadprofile': 0.589452786658276,
#  'region-3-id-311-hh-4-household-electric-load': 0.589452786658276,
#  'region-3-id-27-heatpump-loadprofile': 0.589452786658276,
#  'region-3-id-315-hh-5-household-electric-load': 0.589452786658276,
#  'region-3-id-261-hh-1-household-electric-load': 0.589452786658276,
#  'region-3-id-262-hh-1-household-electric-load': 0.589452786658276,
#  'region-3-id-37-pv-feedin': 0,
#  'region-3-id-263-hh-1-household-electric-load': 0.589452786658276,
#  'region-3-id-264-hh-1-household-electric-load': 0.589452786658276,
#  'region-3-id-283-hh-2-household-electric-load': 0.589452786658276,
#  'region-3-id-284-hh-2-household-electric-load': 0.589452786658276,
#  'region-3-id-25-heatpump-loadprofile': 0.589452786658276,
#  'region-3-id-285-hh-2-household-electric-load': 0.589452786658276,
#  'id-11-data-batterystorage': 0,
#  'region-3-id-286-hh-2-household-electric-load': 0.589452786658276,
#  'region-3-id-265-hh-1-household-electric-load': 0.589452786658276,
#  'region-3-id-266-hh-1-household-electric-load': 0.589452786658276,
#  'region-3-id-293-hh-2-household-electric-load': 0.589452786658276,
#  'region-3-id-305-hh-3-household-electric-load': 0.589452786658276,
#  'region-3-id-306-hh-3-household-electric-load': 0.589452786658276,
#  'region-3-id-28-heatpump-loadprofile': 0.589452786658276,
#  'region-3-id-29-heatpump-loadprofile': 0.589452786658276,
#  'region-3-id-312-hh-4-household-electric-load': 0.589452786658276,
#  'region-3-id-267-hh-1-household-electric-load': 0.589452786658276,
#  'region-3-id-268-hh-1-household-electric-load': 0.589452786658276,
#  'region-3-id-269-hh-1-household-electric-load': 0.589452786658276,
#  'region-3-id-270-hh-1-household-electric-load': 0.589452786658276,
#  'region-3-id-289-hh-2-household-electric-load': 0.589452786658276,
#  'region-3-id-38-pv-feedin': 0,
#  'region-3-id-290-hh-2-household-electric-load': 0.589452786658276,
#  'region-3-id-39-pv-feedin': 0,
#  'region-3-id-291-hh-2-household-electric-load': 0.589452786658276,
#  'region-3-id-292-hh-2-household-electric-load': 0.589452786658276,
#  'region-3-id-271-hh-1-household-electric-load': 0.589452786658276,
#  'region-3-id-272-hh-1-household-electric-load': 0.589452786658276,
#  'region-3-id-298-hh-2-household-electric-load': 0.589452786658276,
#  'region-3-id-307-hh-3-household-electric-load': 0.589452786658276,
#  'region-3-id-30-heatpump-loadprofile': 0.589452786658276,
#  'region-3-id-308-hh-3-household-electric-load': 0.589452786658276,
#  'region-3-id-313-hh-4-household-electric-load': 0.589452786658276,
#  'region-3-id-31-heatpump-loadprofile': 0.589452786658276,
#  'region-3-id-273-hh-1-household-electric-load': 0.589452786658276,
#  'region-3-id-274-hh-1-household-electric-load': 0.589452786658276,
#  'region-3-id-275-hh-1-household-electric-load': 0.589452786658276,
#  'region-3-id-276-hh-1-household-electric-load': 0.589452786658276,
#  'region-3-id-294-hh-2-household-electric-load': 0.589452786658276,
#  'region-3-id-40-pv-feedin': 0,
#  'region-3-id-295-hh-2-household-electric-load': 0.589452786658276,
#  'region-3-id-41-pv-feedin': 0,
#  'region-3-id-296-hh-2-household-electric-load': 0.589452786658276,
#  'region-3-id-297-hh-2-household-electric-load': 0.589452786658276,
#  'region-3-id-277-hh-1-household-electric-load': 0.589452786658276,
#  'region-3-id-43-pv-feedin': 0,
#  'region-3-id-278-hh-1-household-electric-load': 0.589452786658276,
#  'region-3-id-303-hh-2-household-electric-load': 0.589452786658276,
#  'region-3-id-309-hh-3-household-electric-load': 0.589452786658276,
#  'region-3-id-310-hh-3-household-electric-load': 0.589452786658276,
#  'region-3-id-314-hh-4-household-electric-load': 0.589452786658276,
#  'region-3-id-279-hh-1-household-electric-load': 0.589452786658276,
#  'region-3-id-280-hh-1-household-electric-load': 0.589452786658276,
#  'region-3-id-33-heatpump-loadprofile': 0.589452786658276,
#  'region-3-id-281-hh-1-household-electric-load': 0.589452786658276,
#  'region-3-id-282-hh-1-household-electric-load': 0.589452786658276,
#  'region-3-id-32-heatpump-loadprofile': 0.589452786658276,
#  'region-3-id-299-hh-2-household-electric-load': 0.589452786658276,
#  'region-3-id-300-hh-2-household-electric-load': 0.589452786658276,
#  'region-3-id-42-pv-feedin': 0,
#  'region-3-id-301-hh-2-household-electric-load': 0.589452786658276,
#  'region-3-id-302-hh-2-household-electric-load': 0.589452786658276,
#  'region-3-industry-electric-load': 0.589452786658276,
#  'region-4-ec0-house-wind': 0,
#  'region-4-ec1-house-2': 1,
#  'region-4-ec1-house-4': 1,
#  'region-4-ec1-house-6': 1,
#  'region-4-ec1-house-12': 1,
#  'region-4-ec1-house-10': 1,
#  'region-4-ec1-house-0': 1,
#  'region-4-ec1-house-13': 1,
#  'region-4-ec1-house-5': 1,
#  'region-4-ec1-house-15': 1,
#  'region-4-ec1-house-14': 1,
#  'region-4-ec1-house-8': 1,
#  'region-4-ec1-house-11': 1,
#  'region-4-ec1-house-7': 1,
#  'region-4-ec1-house-3': 1,
#  'region-4-ec1-house-16': 1,
#  'region-4-ec1-house-9': 1,
#  'region-4-ec1-house-1': 1,
#  'region-4-ec2-house-6': 1,
#  'region-4-ec2-house-1': 1,
#  'region-4-ec2-house-17': 1,
#  'region-4-ec2-house-4': 1,
#  'region-4-ec2-house-14': 1,
#  'region-4-ec2-house-16': 1,
#  'region-4-ec2-house-2': 1,
#  'region-4-ec2-house-15': 1,
#  'region-4-ec2-house-9': 1,
#  'region-4-ec2-house-10': 1,
#  'region-4-ec2-house-13': 1,
#  'region-4-ec2-house-0': 1,
#  'region-4-ec2-house-8': 1,
#  'region-4-ec2-house-3': 1,
#  'region-4-ec2-house-5': 1,
#  'region-4-ec2-house-7': 1,
#  'region-4-ec2-house-11': 1,
#  'region-4-ec2-house-12': 1,
#  'region-4-ec3-house-9': 1,
#  'region-4-ec3-house-2': 1,
#  'region-4-ec3-house-5': 1,
#  'region-4-ec3-house-0': 1,
#  'region-4-ec3-house-11': 1,
#  'region-4-ec3-house-3': 1,
#  'region-4-ec3-house-17': 1,
#  'region-4-ec3-house-13': 1,
#  'region-4-ec3-house-1': 1,
#  'region-4-ec3-house-4': 1,
#  'region-4-ec3-house-8': 1,
#  'region-4-ec3-house-10': 1,
#  'region-4-ec3-house-6': 1,
#  'region-4-ec3-house-7': 1,
#  'region-4-ec3-house-14': 1,
#  'region-4-ec3-house-16': 1,
#  'region-4-ec3-house-15': 1,
#  'region-4-ec3-house-12': 1,
#  'region-4-ec4-house-10': 1,
#  'region-4-ec4-house-0': 1,
#  'region-4-ec4-house-17': 1,
#  'region-4-ec4-house-7': 1,
#  'region-4-ec4-house-1': 1,
#  'region-4-ec4-house-6': 1,
#  'region-4-ec4-house-12': 1,
#  'region-4-ec4-house-8': 1,
#  'region-4-ec4-house-15': 1,
#  'region-4-ec4-house-3': 1,
#  'region-4-ec4-house-11': 1,
#  'region-4-ec4-house-14': 1,
#  'region-4-ec4-house-5': 1,
#  'region-4-ec4-house-13': 1,
#  'region-4-ec4-house-16': 1,
#  'region-4-ec4-house-2': 1,
#  'region-4-ec4-house-9': 1,
#  'region-4-ec4-house-4': 1,
#  'region-4-ec5-house-industry': 1,
#  'region-4-id-4-wind-feedin': 0,
#  'region-4-id-316-hh-1-household-electric-load': 1,
#  'region-4-id-317-hh-1-household-electric-load': 1,
#  'region-4-id-347-hh-2-household-electric-load': 1,
#  'region-4-id-348-hh-2-household-electric-load': 1,
#  'region-4-id-35-heatpump-loadprofile': 1,
#  'region-4-id-367-hh-3-household-electric-load': 1,
#  'region-4-id-368-hh-3-household-electric-load': 1,
#  'region-4-id-369-hh-3-household-electric-load': 1,
#  'region-4-id-376-hh-4-household-electric-load': 1,
#  'region-4-id-34-heatpump-loadprofile': 1,
#  'region-4-id-377-hh-4-household-electric-load': 1,
#  'region-4-id-45-pv-feedin': 0,
#  'region-4-id-318-hh-1-household-electric-load': 1,
#  'region-4-id-319-hh-1-household-electric-load': 1,
#  'region-4-id-44-pv-feedin': 0,
#  'region-4-id-320-hh-1-household-electric-load': 1,
#  'region-4-id-321-hh-1-household-electric-load': 1,
#  'region-4-id-343-hh-2-household-electric-load': 1,
#  'region-4-id-344-hh-2-household-electric-load': 1,
#  'region-4-id-345-hh-2-household-electric-load': 1,
#  'region-4-id-346-hh-2-household-electric-load': 1,
#  'region-4-id-322-hh-1-household-electric-load': 1,
#  'region-4-id-48-pv-feedin': 0,
#  'region-4-id-323-hh-1-household-electric-load': 1,
#  'region-4-id-352-hh-2-household-electric-load': 1,
#  'region-4-id-37-heatpump-loadprofile': 1,
#  'region-4-id-353-hh-2-household-electric-load': 1,
#  'region-4-id-354-hh-2-household-electric-load': 1,
#  'region-4-id-370-hh-3-household-electric-load': 1,
#  'id-12-data-batterystorage': 0,
#  'region-4-id-371-hh-3-household-electric-load': 1,
#  'region-4-id-378-hh-4-household-electric-load': 1,
#  'region-4-id-379-hh-4-household-electric-load': 1,
#  'region-4-id-47-pv-feedin': 0,
#  'region-4-id-384-hh-5-household-electric-load': 1,
#  'region-4-id-324-hh-1-household-electric-load': 1,
#  'region-4-id-325-hh-1-household-electric-load': 1,
#  'region-4-id-46-pv-feedin': 0,
#  'region-4-id-326-hh-1-household-electric-load': 1,
#  'region-4-id-38-heatpump-loadprofile': 1,
#  'region-4-id-327-hh-1-household-electric-load': 1,
#  'region-4-id-49-pv-feedin': 0,
#  'region-4-id-328-hh-1-household-electric-load': 1,
#  'region-4-id-36-heatpump-loadprofile': 1,
#  'region-4-id-349-hh-2-household-electric-load': 1,
#  'region-4-id-350-hh-2-household-electric-load': 1,
#  'region-4-id-351-hh-2-household-electric-load': 1,
#  'region-4-id-50-pv-feedin': 0,
#  'id-13-data-batterystorage': 0,
#  'region-4-id-329-hh-1-household-electric-load': 1,
#  'region-4-id-330-hh-1-household-electric-load': 1,
#  'region-4-id-358-hh-2-household-electric-load': 1,
#  'region-4-id-359-hh-2-household-electric-load': 1,
#  'region-4-id-41-heatpump-loadprofile': 1,
#  'region-4-id-360-hh-2-household-electric-load': 1,
#  'region-4-id-372-hh-3-household-electric-load': 1,
#  'region-4-id-373-hh-3-household-electric-load': 1,
#  'region-4-id-380-hh-4-household-electric-load': 1,
#  'region-4-id-381-hh-4-household-electric-load': 1,
#  'region-4-id-385-hh-5-household-electric-load': 1,
#  'region-4-id-39-heatpump-loadprofile': 1,
#  'region-4-id-53-pv-feedin': 0,
#  'region-4-id-331-hh-1-household-electric-load': 1,
#  'region-4-id-332-hh-1-household-electric-load': 1,
#  'region-4-id-333-hh-1-household-electric-load': 1,
#  'region-4-id-51-pv-feedin': 0,
#  'region-4-id-334-hh-1-household-electric-load': 1,
#  'region-4-id-335-hh-1-household-electric-load': 1,
#  'region-4-id-355-hh-2-household-electric-load': 1,
#  'region-4-id-356-hh-2-household-electric-load': 1,
#  'region-4-id-40-heatpump-loadprofile': 1,
#  'region-4-id-52-pv-feedin': 0,
#  'region-4-id-357-hh-2-household-electric-load': 1,
#  'region-4-id-55-pv-feedin': 0,
#  'region-4-id-336-hh-1-household-electric-load': 1,
#  'id-14-data-batterystorage': 0,
#  'region-4-id-337-hh-1-household-electric-load': 1,
#  'region-4-id-54-pv-feedin': 0,
#  'region-4-id-364-hh-2-household-electric-load': 1,
#  'region-4-id-365-hh-2-household-electric-load': 1,
#  'region-4-id-366-hh-2-household-electric-load': 1,
#  'region-4-id-43-heatpump-loadprofile': 1,
#  'region-4-id-374-hh-3-household-electric-load': 1,
#  'region-4-id-375-hh-3-household-electric-load': 1,
#  'region-4-id-382-hh-4-household-electric-load': 1,
#  'region-4-id-383-hh-4-household-electric-load': 1,
#  'region-4-id-56-pv-feedin': 0,
#  'region-4-id-386-hh-5-household-electric-load': 1,
#  'region-4-id-338-hh-1-household-electric-load': 1,
#  'region-4-id-339-hh-1-household-electric-load': 1,
#  'region-4-id-340-hh-1-household-electric-load': 1,
#  'region-4-id-341-hh-1-household-electric-load': 1,
#  'region-4-id-342-hh-1-household-electric-load': 1,
#  'region-4-id-57-pv-feedin': 0,
#  'region-4-id-361-hh-2-household-electric-load': 1,
#  'region-4-id-44-heatpump-loadprofile': 1,
#  'region-4-id-362-hh-2-household-electric-load': 1,
#  'region-4-id-42-heatpump-loadprofile': 1,
#  'region-4-id-363-hh-2-household-electric-load': 1,
#  'region-4-industry-electric-load': 1,
#  'region-5-ec0-house-wind': 0,
#  'region-5-ec1-house-0': 1,
#  'region-5-ec1-house-7': 1,
#  'region-5-ec1-house-2': 1,
#  'region-5-ec1-house-9': 1,
#  'region-5-ec1-house-13': 1,
#  'region-5-ec1-house-11': 1,
#  'region-5-ec1-house-3': 1,
#  'region-5-ec1-house-10': 1,
#  'region-5-ec1-house-6': 1,
#  'region-5-ec1-house-1': 1,
#  'region-5-ec1-house-12': 1,
#  'region-5-ec1-house-4': 1,
#  'region-5-ec1-house-14': 1,
#  'region-5-ec1-house-8': 1,
#  'region-5-ec1-house-5': 1,
#  'region-5-ec1-house-15': 1,
#  'region-5-ec2-house-13': 1,
#  'region-5-ec2-house-12': 1,
#  'region-5-ec2-house-7': 1,
#  'region-5-ec2-house-8': 1,
#  'region-5-ec2-house-6': 1,
#  'region-5-ec2-house-1': 1,
#  'region-5-ec2-house-11': 1,
#  'region-5-ec2-house-3': 1,
#  'region-5-ec2-house-4': 1,
#  'region-5-ec2-house-17': 1,
#  'region-5-ec2-house-14': 1,
#  'region-5-ec2-house-15': 1,
#  'region-5-ec2-house-0': 1,
#  'region-5-ec2-house-2': 1,
#  'region-5-ec2-house-5': 1,
#  'region-5-ec2-house-10': 1,
#  'region-5-ec2-house-16': 1,
#  'region-5-ec2-house-9': 1,
#  'region-5-ec3-house-8': 1,
#  'region-5-ec3-house-4': 1,
#  ...}
