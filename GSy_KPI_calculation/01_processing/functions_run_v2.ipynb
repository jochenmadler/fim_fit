# %% [markdown]
# # KPI Calculation
# ---
# There are four KPIs calculated. As GSy's model is hierarchical, each KPI is calculated for several levels
# * **Average electricity price and cost per timestep** (done)
#     - germany
#     - regions
#     - ecs
#     - assets
# * **Total electricity costs** (done)
#     - germany
#     - market_maker
#     - regions
#     - ecs
#     - other_assets
# * **Share of renewable energy consumed** (tbd)
#     - germany
#     - regions
#     - ecs
# * **C02 emissions of energy consumed** (tbd)
#     - germany
#     - regions
#     - ecs

# %% [markdown]
# ## Set up
# ---
# The `home_path` is set to: ..\Projekt VIdES - Dokumente\General\\07_Arbeitsordner\\04_Ergebnisse\\20220907_erste_Ergebnisse_UseCases.
# The `get_kpi_dict()` function takes the `home_path` and the `kpi` (nr. 1-4) as input. For each kpi, it returns the following structure:
# * usecase_0
#     - sublevels
# * usecase_1 (no data yet)
#     - sublevels
# * usecase_2
#     - sublevels
# * usecase_3 (no data yet)
#     - sublevels
# * usecase_4
#     - sublevels
#
# The sublevels' names are the same as the KPI levels defined above (e.g. germany, regions, ecs).

# %%
# set up
import os
import pandas as pd
import functools as func
import functions as f
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('white')
home_path = "C:\\Users\joche\FIM Kernkompetenzzentrum\Projekt VIdES - Dokumente\General\\07_Arbeitsordner\\04_Ergebnisse\\20220907_erste_Ergebnisse_UseCases"
os.chdir(home_path)

# %% [markdown]
# ## KPI 1: Average electricity price and cost per timestep
# ---

# %%
# example: obtain KPI 1 for all energy communities of usecase 4
kpi1 = f.get_kpi_dict(home_path, kpi=1)
kpi1['usecase_4']['ecs']
# Out:
#                          slot  region1_ec0_avg trade rate [ct./kWh]  \
# 0   2030-01-01T00:00:00+00:00                                  7.68
# 1   2030-01-01T01:00:00+00:00                                  7.68
# 2   2030-01-01T02:00:00+00:00                                  7.68
# 3   2030-01-01T03:00:00+00:00                                  7.68
# 4   2030-01-01T04:00:00+00:00                                  7.68
# 5   2030-01-01T05:00:00+00:00                                  7.68
# 6   2030-01-01T06:00:00+00:00                                  7.68
# 7   2030-01-01T07:00:00+00:00                                  7.68
# 8   2030-01-01T08:00:00+00:00                                  7.68
# 9   2030-01-01T09:00:00+00:00                                  7.68
# 10  2030-01-01T10:00:00+00:00                                  7.68
# 11  2030-01-01T11:00:00+00:00                                  7.68
# 12  2030-01-01T12:00:00+00:00                                  7.68
# 13  2030-01-01T13:00:00+00:00                                  7.68
# 14  2030-01-01T14:00:00+00:00                                  7.68
# 15  2030-01-01T15:00:00+00:00                                  7.68
# 16  2030-01-01T16:00:00+00:00                                  7.68
# 17  2030-01-01T17:00:00+00:00                                  7.68
# 18  2030-01-01T18:00:00+00:00                                  7.68
# 19  2030-01-01T19:00:00+00:00                                  7.68
# 20  2030-01-01T20:00:00+00:00                                  7.68
# 21  2030-01-01T21:00:00+00:00                                  7.68
# 22  2030-01-01T22:00:00+00:00                                  7.68
# 23  2030-01-01T23:00:00+00:00                                  7.68
#
#     region1_ec0_total trade volume [EURO ct.]  \
# 0                                  968.755864
# 1                                  934.147152
# 2                                  916.407194
# 3                                  917.485670
# 4                                  944.521185
# 5                                 1007.631031
# 6                                 1063.163295
# 7                                 1082.227772
# 8                                 1009.553123
# 9                                  898.167340
# 10                                 934.086560
# 11                                 994.744123
# 12                                 998.335795
# 13                                 965.888782
# 14                                 966.216606
# 15                                1077.502566
# 16                                1151.502752
# 17                                1242.202191
# 18                                1339.578793
# 19                                1294.553099
# 20                                1093.267436
# 21                                 970.130495
# 22                                 868.241278
# 23                                 836.961768
#
#     region1_ec1_avg trade rate [ct./kWh]  \
# 0                                  20.99
# 1                                  20.99
# 2                                  20.99
# 3                                  20.99
# 4                                  20.99
# 5                                  20.99
# 6                                  20.99
# 7                                  20.99
# 8                                  20.99
# 9                                  20.99
# 10                                 20.99
# 11                                 20.99
# 12                                 20.99
# 13                                 20.99
# 14                                 20.99
# 15                                 20.99
# 16                                 20.99
# 17                                 20.99
# 18                                 20.99
# 19                                 20.99
# 20                                 20.99
# 21                                 20.99
# 22                                 20.99
# 23                                 20.99
#
#     region1_ec1_total trade volume [EURO ct.]  \
# 0                                  610.709282
# 1                                  615.045398
# 2                                  621.158555
# 3                                  617.042698
# 4                                  635.158253
# 5                                  611.769014
# 6                                  647.041656
# 7                                  626.729943
# 8                                  555.288873
# 9                                  520.932909
# 10                                 454.371770
# 11                                 325.384716
# 12                                 280.050305
# 13                                 365.910782
# 14                                 570.652210
# 15                                 676.382875
# 16                                 720.816650
# 17                                 738.781846
# 18                                 702.787061
# 19                                 649.037341
# 20                                 614.560976
# 21                                 582.729217
# 22                                 591.077975
# 23                                 628.147180
#
#     region1_ec2_avg trade rate [ct./kWh]  \
# 0                                  20.99
# 1                                  20.99
# 2                                  20.99
# 3                                  20.99
# 4                                  20.99
# 5                                  20.99
# 6                                  20.99
# 7                                  20.99
# 8                                  20.99
# 9                                  20.99
# 10                                 20.99
# 11                                 20.99
# 12                                 20.99
# 13                                 20.99
# 14                                 20.99
# 15                                 20.99
# 16                                 20.99
# 17                                 20.99
# 18                                 20.99
# 19                                 20.99
# 20                                 20.99
# 21                                 20.99
# 22                                 20.99
# 23                                 20.99
#
#     region1_ec2_total trade volume [EURO ct.]  \
# 0                                  609.468714
# 1                                  657.921773
# 2                                  633.633318
# 3                                  615.496595
# 4                                  720.349606
# 5                                  616.147756
# 6                                  621.342817
# 7                                  668.276289
# 8                                  532.379314
# 9                                  515.067282
# 10                                 396.857744
# 11                                 390.345432
# 12                                 218.298233
# 13                                 360.165530
# 14                                 578.228610
# 15                                 605.470490
# 16                                 753.446649
# 17                                 801.161513
# 18                                 720.636883
# 19                                 657.329466
# 20                                 662.683208
# 21                                 604.453529
# 22                                 617.346131
# 23                                 662.272505
#
#     region1_ec3_avg trade rate [ct./kWh]  \
# 0                                  20.99
# 1                                  20.99
# 2                                  20.99
# 3                                  20.99
# 4                                  20.99
# 5                                  20.99
# 6                                  20.99
# 7                                  20.99
# 8                                  20.99
# 9                                  20.99
# 10                                 20.99
# 11                                 20.99
# 12                                 20.99
# 13                                 20.99
# 14                                 20.99
# 15                                 20.99
# 16                                 20.99
# 17                                 20.99
# 18                                 20.99
# 19                                 20.99
# 20                                 20.99
# 21                                 20.99
# 22                                 20.99
# 23                                 20.99
#
#     region1_ec3_total trade volume [EURO ct.]  \
# 0                                  664.704290
# 1                                  730.610302
# 2                                  648.871395
# 3                                  643.011808
# 4                                  785.439881
# 5                                  628.542829
# 6                                  620.853467
# 7                                  645.985370
# 8                                  502.551606
# 9                                  428.876143
# 10                                 372.872120
# 11                                 289.321086
# 12                                 238.697607
# 13                                 325.967316
# 14                                 573.667869
# 15                                 614.592639
# 16                                 711.142778
# 17                                 803.606970
# 18                                 663.050186
# 19                                 638.729729
# 20                                 659.151190
# 21                                 581.884732
# 22                                 598.435925
# 23                                 708.549383
#
#     region1_ec4_avg trade rate [ct./kWh]  ...  \
# 0                                  20.99  ...
# 1                                  20.99  ...
# 2                                  20.99  ...
# 3                                  20.99  ...
# 4                                  20.99  ...
# 5                                  20.99  ...
# 6                                  20.99  ...
# 7                                  20.99  ...
# 8                                  20.99  ...
# 9                                  20.99  ...
# 10                                 20.99  ...
# 11                                 20.99  ...
# 12                                 20.99  ...
# 13                                 20.99  ...
# 14                                 20.99  ...
# 15                                 20.99  ...
# 16                                 20.99  ...
# 17                                 20.99  ...
# 18                                 20.99  ...
# 19                                 20.99  ...
# 20                                 20.99  ...
# 21                                 20.99  ...
# 22                                 20.99  ...
# 23                                 20.99  ...
#
#     region6_ec1_avg trade rate [ct./kWh]  \
# 0                                  20.99
# 1                                  20.99
# 2                                  20.99
# 3                                  20.99
# 4                                  20.99
# 5                                  20.99
# 6                                  20.99
# 7                                  20.99
# 8                                   7.68
# 9                                   7.68
# 10                                  7.68
# 11                                  7.68
# 12                                  7.68
# 13                                  7.68
# 14                                 20.99
# 15                                 20.99
# 16                                 20.99
# 17                                 20.99
# 18                                 20.99
# 19                                 20.99
# 20                                 20.99
# 21                                 20.99
# 22                                 20.99
# 23                                 20.99
#
#     region6_ec1_total trade volume [EURO ct.]  \
# 0                                  950.680758
# 1                                 1004.345714
# 2                                  894.869840
# 3                                  907.481560
# 4                                 1009.550988
# 5                                  906.492461
# 6                                  889.949566
# 7                                  594.976605
# 8                                  167.302002
# 9                                  409.330423
# 10                                 476.063454
# 11                                 537.710517
# 12                                 499.590200
# 13                                 325.875493
# 14                                  30.045026
# 15                                 860.241697
# 16                                 928.527394
# 17                                1035.667289
# 18                                 999.449060
# 19                                 886.809542
# 20                                 884.586743
# 21                                 836.890711
# 22                                 829.448102
# 23                                 916.290133
#
#     region6_ec2_avg trade rate [ct./kWh]  \
# 0                                  20.99
# 1                                  20.99
# 2                                  20.99
# 3                                  20.99
# 4                                  20.99
# 5                                  20.99
# 6                                  20.99
# 7                                  20.99
# 8                                   7.68
# 9                                   7.68
# 10                                  7.68
# 11                                  7.68
# 12                                  7.68
# 13                                  7.68
# 14                                 20.99
# 15                                 20.99
# 16                                 20.99
# 17                                 20.99
# 18                                 20.99
# 19                                 20.99
# 20                                 20.99
# 21                                 20.99
# 22                                 20.99
# 23                                 20.99
#
#     region6_ec2_total trade volume [EURO ct.]  \
# 0                                  873.268441
# 1                                  924.673255
# 2                                  838.907116
# 3                                  813.234542
# 4                                  975.255212
# 5                                  875.853235
# 6                                  869.170030
# 7                                  556.085556
# 8                                   85.351699
# 9                                  337.399928
# 10                                 409.712887
# 11                                 452.805513
# 12                                 409.469716
# 13                                 266.489340
# 14                                  60.682287
# 15                                 720.151627
# 16                                 758.178577
# 17                                 883.880210
# 18                                 950.720157
# 19                                 891.103300
# 20                                 877.672778
# 21                                 816.449613
# 22                                 786.808948
# 23                                 890.213851
#
#     region6_ec3_avg trade rate [ct./kWh]  \
# 0                                  20.99
# 1                                  20.99
# 2                                  20.99
# 3                                  20.99
# 4                                  20.99
# 5                                  20.99
# 6                                  20.99
# 7                                  20.99
# 8                                   7.68
# 9                                   7.68
# 10                                  7.68
# 11                                  7.68
# 12                                  7.68
# 13                                  7.68
# 14                                 20.99
# 15                                 20.99
# 16                                 20.99
# 17                                 20.99
# 18                                 20.99
# 19                                 20.99
# 20                                 20.99
# 21                                 20.99
# 22                                 20.99
# 23                                 20.99
#
#     region6_ec3_total trade volume [EURO ct.]  \
# 0                                  846.387760
# 1                                  910.946857
# 2                                  789.033966
# 3                                  790.455869
# 4                                 1096.224112
# 5                                  914.503316
# 6                                  871.181415
# 7                                  549.628705
# 8                                  117.742575
# 9                                  327.113392
# 10                                 383.221080
# 11                                 457.572272
# 12                                 406.392811
# 13                                 253.521037
# 14                                 106.955077
# 15                                 815.092706
# 16                                 784.257470
# 17                                 876.768763
# 18                                 907.254518
# 19                                 914.002142
# 20                                 842.705852
# 21                                 855.465879
# 22                                 860.702050
# 23                                 912.578799
#
#     region6_ec4_avg trade rate [ct./kWh]  \
# 0                                  20.99
# 1                                  20.99
# 2                                  20.99
# 3                                  20.99
# 4                                  20.99
# 5                                  20.99
# 6                                  20.99
# 7                                  20.99
# 8                                   7.68
# 9                                   7.68
# 10                                  7.68
# 11                                  7.68
# 12                                  7.68
# 13                                  7.68
# 14                                 20.99
# 15                                 20.99
# 16                                 20.99
# 17                                 20.99
# 18                                 20.99
# 19                                 20.99
# 20                                 20.99
# 21                                 20.99
# 22                                 20.99
# 23                                 20.99
#
#     region6_ec4_total trade volume [EURO ct.]  \
# 0                                  897.261482
# 1                                  946.363607
# 2                                  895.757540
# 3                                  962.234726
# 4                                 1028.507704
# 5                                  917.979337
# 6                                  923.739187
# 7                                  628.570864
# 8                                   76.531346
# 9                                  290.685819
# 10                                 379.109923
# 11                                 448.750121
# 12                                 398.308275
# 13                                 245.002245
# 14                                  36.710470
# 15                                 799.868387
# 16                                 840.051943
# 17                                 949.724852
# 18                                 933.327969
# 19                                 879.182111
# 20                                 847.243854
# 21                                 820.132054
# 22                                 811.463256
# 23                                 913.123002
#
#     region6_ec5_avg trade rate [ct./kWh]  \
# 0                                  20.99
# 1                                  20.99
# 2                                  20.99
# 3                                  20.99
# 4                                  20.99
# 5                                  20.99
# 6                                  20.99
# 7                                  20.99
# 8                                  20.99
# 9                                  20.99
# 10                                 20.99
# 11                                 20.99
# 12                                 20.99
# 13                                 20.99
# 14                                 20.99
# 15                                 20.99
# 16                                 20.99
# 17                                 20.99
# 18                                 20.99
# 19                                 20.99
# 20                                 20.99
# 21                                 20.99
# 22                                 20.99
# 23                                 20.99
#
#     region6_ec5_total trade volume [EURO ct.]
# 0                                 1358.372766
# 1                                 1317.631412
# 2                                 1340.818527
# 3                                 1358.843679
# 4                                 1367.861973
# 5                                 1361.110751
# 6                                 1371.819090
# 7                                 1387.269533
# 8                                 1329.835597
# 9                                 1325.543534
# 10                                1321.535889
# 11                                1270.483157
# 12                                1280.300271
# 13                                1279.730825
# 14                                1246.701993
# 15                                1294.962038
# 16                                1293.771062
# 17                                1344.885302
# 18                                1394.838960
# 19                                1444.821918
# 20                                1442.740422
# 21                                1478.010552
# 22                                1502.425157
# 23                                1519.273089
#
# [24 rows x 73 columns]

# %%
# example: obtain KPI 1 for all assets of usecase 2
all_assets = kpi1['usecase_2']['assets']
fig, axs = plt.subplots(figsize = (18,6), ncols=2)
all_assets[all_assets.columns[1::2]].plot(legend=False, title= f'avg. trade rate of {len(all_assets.columns)} assets', xlabel = 'timesteps', ylabel = 'ct/kWh', colormap ='viridis', linewidth = 0.5, ax = axs[0])
all_assets[all_assets.columns[::2]].plot(legend=False, title= f'total trade volume of {len(all_assets.columns)} assets', xlabel = 'timesteps', ylabel = 'ct', colormap ='plasma', linewidth = 0.5, ax = axs[1])
plt.tight_layout()
plt.show()

# %% [markdown]
# ## KPI 2: Total electricity costs
# ---

# %%
# example: obtain KPI 2 for all regions of use case 2
kpi2 = f.get_kpi_dict(home_path, kpi=2)
kpi2['usecase_2']['regions']
# Out:
#                                           name     total
# bc2676a8-8a23-4791-853d-856ebad3c668  Region_5   896.457
# 1c1b23be-b25f-47b2-8232-2159e9243c6b  Region_2  1766.246
# 00d6cc5a-f8d4-4966-ade0-1a4227d12dde  Region_3   454.333
# 295da7d8-fff7-48d3-bf90-1589408d22c6  Region_4   813.485
# a6b4459e-6260-4064-8ac3-9c3cb7c943a9  Region_1   765.892
# 69d8ce03-8762-4780-b8f6-48c511731c2d  Region_6  1003.195

# %% [markdown]
# ## KPI 3: Share of renewable energy consumed (tbd)
# ---

# %%
os.chdir(home_path)
os.chdir('usecase_0/')
os.chdir('aggregated_results/')
df_0 = pd.read_json('trade_profile.json')
df_0
# Out:
#                                        Region_5_ID_5_Wind_FeedIn  \
# sold_energy    {'Region_5_ID_5_Wind_FeedIn': {'accumulated': ...
# bought_energy  {'Region_5_EC0_house_Wind': {'accumulated': {'...
#
#                                          Region_5_EC0_house_Wind  \
# sold_energy    {'Region_5_ID_5_Wind_FeedIn': {'accumulated': ...
# bought_energy  {'Region_5_EC0_house_Wind': {'accumulated': {'...
#
#                                       MM_Region_5_EC0_house_Wind  \
# sold_energy    {'Region_5_EC0_house_Wind': {'accumulated': {'...
# bought_energy  {'MM_Region_5_EC0_house_Wind': {'accumulated':...
#
#                                   Member_Region_5_EC0_house_Wind Region_5_EC0  \
# sold_energy    {'Region_5_EC0_house_Wind': {'accumulated': {'...           {}
# bought_energy  {'MM_Region_5_EC0_house_Wind': {'accumulated':...           {}
#
#                     Region_5_ID_447_HH_4_Household_Electric_Load  \
# sold_energy    {'Region_5_EC1_house_15': {'accumulated': {'Ja...
# bought_energy  {'Region_5_ID_447_HH_4_Household_Electric_Load...
#
#                                            Region_5_EC1_house_15  \
# sold_energy    {'Region_5_EC1_house_15': {'accumulated': {'Ja...
# bought_energy  {'Region_5_ID_447_HH_4_Household_Electric_Load...
#
#                                         MM_Region_5_EC1_house_15  \
# sold_energy    {'MM_Region_5_EC1_house_15': {'accumulated': {...
# bought_energy  {'Region_5_EC1_house_15': {'accumulated': {'Ja...
#
#                                     Member_Region_5_EC1_house_15  \
# sold_energy    {'MM_Region_5_EC1_house_15': {'accumulated': {...
# bought_energy  {'Region_5_EC1_house_15': {'accumulated': {'Ja...
#
#                                                  ID_3_EV_HHChild  ...  \
# sold_energy    {'Region_5_EC1_house_12': {'accumulated': {'Ja...  ...
# bought_energy  {'ID_3_EV_HHChild': {'accumulated': {'January ...  ...
#
#                                      Member_Region_6_EC2_house_0  \
# sold_energy    {'MM_Region_6_EC2_house_0': {'accumulated': {'...
# bought_energy  {'Region_6_EC2_house_0': {'accumulated': {'Jan...
#
#                                         Region_6_ID_94_PV_FeedIn  \
# sold_energy    {'Region_6_ID_94_PV_FeedIn': {'accumulated': {...
# bought_energy  {'ID_3_EV_HHChild': {'accumulated': {'January ...
#
#                              Region_6_ID_70_Heatpump_Loadprofile  \
# sold_energy    {'Region_6_EC2_house_7': {'accumulated': {'Jan...
# bought_energy  {'Region_6_ID_70_Heatpump_Loadprofile': {'accu...
#
#                     Region_6_ID_473_HH_1_Household_Electric_Load  \
# sold_energy    {'Region_6_EC2_house_7': {'accumulated': {'Jan...
# bought_energy  {'Region_6_ID_473_HH_1_Household_Electric_Load...
#
#                                             Region_6_EC2_house_7  \
# sold_energy    {'Region_6_EC2_house_7': {'accumulated': {'Jan...
# bought_energy  {'ID_3_EV_HHChild': {'accumulated': {'January ...
#
#                                          MM_Region_6_EC2_house_7  \
# sold_energy    {'MM_Region_6_EC2_house_7': {'accumulated': {'...
# bought_energy  {'Region_6_EC2_house_7': {'accumulated': {'Jan...
#
#                                      Member_Region_6_EC2_house_7 Region_6_EC2  \
# sold_energy    {'MM_Region_6_EC2_house_7': {'accumulated': {'...           {}
# bought_energy  {'Region_6_EC2_house_7': {'accumulated': {'Jan...           {}
#
#               Region_6 Germany
# sold_energy         {}      {}
# bought_energy       {}      {}
#
# [2 rows x 2488 columns]

# %% [markdown]
# #### Use case 0: Every asset buys energy from the market (reference case)
# In use case 0, p2p trading is disabled. Every asset can trade with the external market through its own MM-entity.
# Therefore, every asset procures its energy from the German electricity mix, with a renewables share of ~ 42% (look for external source).

# %% [markdown]
# #### Use case 2:
# In use case 2, p2p trading is enabled on all levels.
